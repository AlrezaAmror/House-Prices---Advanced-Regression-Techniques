# %% [markdown]
# **Latar Belakang**
#
# Dewasa ini penentuan harga rumah merupakan hal yang sangat penting. Harga rumah dapat dipengaruhi oleh berbagi macam faktor seperti lokasi, luas tanah, luas bangunan, jumlah kamar, dll. Namun menentukan harga rumah yang tepat menjadi tantangan tersendiri karena kompleksitas dari faktor-faktor yang mempengaruhi. Perkembangan dalam bidang teknologi dan Data Science memungkinkan menggunkan metode baru dalam menyelesaikan problem ini. salah satunya adalah dengan menggunakan pendekatan Machine Learning.
#
# **Problem Statement**
#
# masalah yang ingin saya selesaikan adalah melakukan explorasi data untuk membuat model yang akurat dalam memprediksi harga rumah
#
# dataset yang saya gunakan adalah dataset yang berasal dari [kaggle](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques) Dengan 79 variabel penjelas yang menggambarkan (hampir) setiap aspek rumah hunian di Ames, Iowa. berikut deskripsi singkat dari tiap variabel
#
# * SalePrice - harga jual properti dalam dolar. Ini adalah variabel target yang Anda coba prediksi.
# * MSSubClass: Kelas bangunan
# * MSZoning: Klasifikasi zonasi umum
# * LotFrontage: Kaki linier jalan yang terhubung ke properti
# * LotArea: Ukuran lot dalam kaki persegi
# * Street: Jenis akses jalan
# * Alley: Jenis akses gang
# * LotShape: Bentuk umum properti
# * LandContour: Kerataan properti
# * Utilities: Jenis utilitas yang tersedia
# * LotConfig: Konfigurasi lot
# * LandSlope: Kemiringan properti
# * Neighborhood: Lokasi fisik dalam batas kota Ames
# * Condition1: Dekat dengan jalan utama atau kereta api
# * Condition2: Kedekatan dengan jalan utama atau kereta api (jika ada detik)
# * BldgType: Jenis tempat tinggal
# * HouseStyle: Gaya hunian
# * OverallQual: Bahan keseluruhan dan kualitas akhir
# * OverallCond: Peringkat kondisi keseluruhan
# * TahunDibangun: Tanggal konstruksi asli
# * YearRemodAdd: Merombak tanggal
# * RoofStyle: Jenis atap
# * RoofMatl: Bahan atap
# * Exterior1st: Penutup eksterior di rumah
# * Exterior2nd: Penutup eksterior pada rumah (jika lebih dari satu material)
# * MasVnrType: Jenis veneer Masonry
# * MasVnrArea: Area veneer Masonry dalam kaki persegi
# * ExterQual: Kualitas material eksterior
# * ExterCond: Kondisi material saat ini pada eksterior
# * Foundation: Jenis pondasi
# * BsmtQual: Ketinggian ruang bawah tanah
# * BsmtCond: Kondisi umum ruang bawah tanah
# * BsmtExposure: Walkout atau dinding basement tingkat taman
# * BsmtFinType1: Kualitas area jadi basement
# * BsmtFinSF1: Tipe 1 kaki persegi jadi
# * BsmtFinType2: Kualitas area jadi kedua (jika ada)
# * BsmtFinSF2: Tipe 2 kaki persegi jadi
# * BsmtUnfSF: Kaki persegi area basement yang belum selesai
# * TotalBsmtSF: Total kaki persegi area basement
# * Heating: Jenis pemanasan
# * HeatingQC: Kualitas dan kondisi pemanasan
# * CentralAir: AC sentral
# * Electrical: Sistem kelistrikan
# * 1stFlrSF: Kaki persegi lantai pertama
# * 2ndFlrSF: Kaki persegi lantai dua
# * LowQualFinSF: Kaki persegi jadi berkualitas rendah (semua lantai)
# * GrLivArea: Ruang tamu kelas atas (tanah) kaki persegi
# * BsmtFullBath: Ruang bawah tanah kamar mandi lengkap
# * BsmtHalfBath: Ruang bawah tanah setengah kamar mandi
# * FullBath: Kamar mandi lengkap di atas kelas
# * HalfBath: Setengah mandi di atas kelas
# * Bedroom: Jumlah kamar tidur di atas lantai basement
# * Kitchen: Jumlah dapur
# * KitchenQual: Kualitas dapur
# * TotRmsAbvGrd: Total kamar di atas kelas (tidak termasuk kamar mandi)
# * Fungsional: Peringkat fungsionalitas rumah
# * Fireplaces: Jumlah perapian
# * FireplaceQu: Kualitas perapian
# * GarageType: Lokasi garasi
# * GarageYrBlt: Tahun garasi dibangun
# * GarageFinish: Finishing interior garasi
# * GarageCars: Ukuran garasi dalam kapasitas mobil
# * GarageArea: Ukuran garasi dalam kaki persegi
# * GarageQual: Kualitas garasi
# * GarageCond: Kondisi garasi
# * PavedDrive: Jalan masuk beraspal
# * WoodDeckSF: Area dek kayu dalam kaki persegi
# * OpenPorchSF: Area teras terbuka dalam kaki persegi
# * EnclosedPorch: Area teras tertutup dalam kaki persegi
# * 3SsnPorch: Area teras tiga musim dalam kaki persegi
# * ScreenPorch: Area teras layar dalam kaki persegi
# * PoolArea: Area kolam dalam kaki persegi
# * PoolQC: Kualitas kolam
# * Fence: Kualitas pagar
# * MiscFeature: Fitur lain-lain yang tidak tercakup dalam kategori lain
# * MiscVal: $Value fitur lain-lain
# * MoSold: Bulan Terjual
# * YrSold: Tahun Terjual
# * SaleType: Jenis penjualan
# * SaleCondition: Kondisi penjualan

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
sns.set(style="darkgrid",font_scale=1.5)
pd.set_option("display.max.columns",9999)
pd.set_option("display.max.rows",9999)

from scipy import stats
from scipy.stats import skew,norm
from scipy.special import boxcox1p
from scipy.special import boxcox
from scipy.stats import boxcox_normmax

from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
# !pip install catboost
from catboost import CatBoostRegressor
from mlxtend.regressor import StackingCVRegressor

from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import RobustScaler, StandardScaler, LabelEncoder, OneHotEncoder, FunctionTransformer
# !pip install category_encoders
from category_encoders import HashingEncoder
from google.colab import drive
drive.mount('/content/drive')
traindata = pd.read_csv('/content/drive/MyDrive/Competition & Project/Kaggle-Predicting House/train.csv')
testdata = pd.read_csv('/content/drive/MyDrive/Competition & Project/Kaggle-Predicting House/test.csv')

# %%
file_path = '/content/drive/MyDrive/Competition & Project/Kaggle-Predicting House/data_description.txt'
with open(file_path, 'r') as file:
    metadata = file.read()
print(metadata)
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %% [markdown]
# # First Look

# %%
traindata.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
testdata.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
traindata.describe(include = [int, float])
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
traindata.describe(include = ['O'])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# ...

# %%
testdata.describe(include = [int, float])
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# ...

# %%
testdata.describe(include = ['O'])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1455   1459   107     1459        1459      1457      1459
# unique        5      2     2        4           4         1         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1114   1453    70      934        1311      1457      1081
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1459         1459       1459       1459     1459       1459
# unique         3           25          9          5        5          7
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1396          218       1251       1444     1205        745
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1459     1459        1458        1458       1443      1459
# unique         6        4          13          15          4         4
# ...

# %% [markdown]
# # EDA dan Data Cleaning

# %% [markdown]
# ### Data SalePrice

# %%
plt.figure(figsize = (15,4))
plt.subplot(1,3,1)
sns.histplot(traindata['SalePrice'], color = 'red', kde = True)
plt.title('Distribusi Data SalePrice', size = 20, pad = 10)
plt.subplot(1,3,2)
sns.boxplot(traindata['SalePrice'])
plt.title('Cek Outlier')
plt.subplot(1,3,3)
stats.probplot(traindata["SalePrice"], plot = sns.mpl.pyplot)
plt.title("QQ-Norm")
plt.show()

# %%
plt.figure(figsize = (15,6))
plt.subplot(1,3,1)
sns.distplot(traindata['SalePrice'], kde=False, fit=stats.johnsonsu,color="red")
plt.title("Transformasi Jhonson")
plt.subplot(1,3,2)
sns.distplot(traindata['SalePrice'], kde = False, fit = stats.norm, color = 'green')
plt.title("Transformasi Normal")
plt.subplot(1,3,3)
sns.distplot(traindata['SalePrice'], kde = False, fit = stats.lognorm, color = 'blue')
plt.title("Transformasi Log Normal")
plt.show()

# %%
# Applying log transformation
traindata['SalePrice'] = np.log(traindata['SalePrice'])
plt.figure(figsize = (15,4))
plt.subplot(1,3,1)
sns.histplot(traindata['SalePrice'], color = 'red', kde = True)
plt.title('Distribusi Data SalePrice', size = 20, pad = 10)
plt.subplot(1,3,2)
sns.boxplot(traindata['SalePrice'])
plt.title('Cek Outlier')
plt.subplot(1,3,3)
stats.probplot(traindata['SalePrice'], plot = sns.mpl.pyplot)
plt.title("QQ-Norm")
plt.show()

# %% [markdown]
# ### Data Prediktor
#
# * Quantitatif
#
# > 1. Diskrit => data dengan nilai yang diskrit (exp : jumlah pengangguran)
# > 2. Kontinu => data dengan nilai yang kontinu (exp : berat badan siswa)
#
# * Qualitatif
#
# > 1. Ordinal => data kategorik yang bisa diurutkan (exp : tingkat pendidikan)
# > 2. Nominal => data kategorik yang diskrit (exp : warna)
#
# Dengan mengetahui tipe data yang akan digunakan untuk prediksi saya bisa membuat keputusan mengenai bagaimana data-data tersebut akan dieksekusi seperti handling missing value, encoding data qualitatif, dan membuat analisis statistika

# %%
QUANTITATIVE_COLS = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
                     '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageYrBlt', 'GarageArea', 'BsmtFullBath', 'BsmtHalfBath',
                     'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces','GarageCars',  'WoodDeckSF',
                     'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']
ORDINAL_COLS = ['Utilities', 'LandSlope', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'ExterQual', 'ExterCond',
              'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', "Heating", 'HeatingQC', 'KitchenQual',
              'FireplaceQu', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
              'YrSold', 'MoSold', "Condition1", "Condition2"]
NOMINAL_COLS = list(set(traindata.columns) - set(QUANTITATIVE_COLS + ORDINAL_COLS + ['SalePrice']))

# %%
def getType(colname):
  if colname in QUANTITATIVE_COLS+["SalePrice"]:
    return 'quantitative'
  elif colname in ORDINAL_COLS:
    return 'ordinal'
  else:
    return 'nominal'

# %% [markdown]
# #### Handling Missing Value
#
# Melakukan penanganan pada data hilang. Terdapat beberapa teknik atau metode tergantung dari karakteristik data
#
# Pengisian data hilang dilakukan dikedua dataset

# %%
column = []
null = []
pctgnull = []
tipe = []
for col in traindata.columns:
  column.append(col)
  null.append(traindata[col].isna().sum())
  pctgnull.append((traindata[col].isna().sum()/len(traindata))*100)
  tipe.append(getType(col))

NullTrain = pd.DataFrame({'column':column, 'null':null, 'pctgnull':pctgnull, 'type':tipe})
NullTrain[NullTrain.null>0].sort_values(by='null', ascending=False).reset_index(drop = True)
# Out:
#           column  null   pctgnull          type
# 0         PoolQC  1453  99.520548       ordinal
# 1    MiscFeature  1406  96.301370       nominal
# 2          Alley  1369  93.767123       nominal
# 3          Fence  1179  80.753425       ordinal
# 4    FireplaceQu   690  47.260274       ordinal
# 5    LotFrontage   259  17.739726  quantitative
# 6     GarageType    81   5.547945       nominal
# 7    GarageYrBlt    81   5.547945  quantitative
# 8   GarageFinish    81   5.547945       ordinal
# 9     GarageQual    81   5.547945       ordinal
# 10    GarageCond    81   5.547945       ordinal
# 11  BsmtExposure    38   2.602740       ordinal
# 12  BsmtFinType2    38   2.602740       ordinal
# 13  BsmtFinType1    37   2.534247       ordinal
# 14      BsmtCond    37   2.534247       ordinal
# 15      BsmtQual    37   2.534247       ordinal
# 16    MasVnrArea     8   0.547945  quantitative
# 17    MasVnrType     8   0.547945       nominal
# 18    Electrical     1   0.068493       nominal

# %%
column_test = []
null = []
pctgnull = []
tipe = []
for col in testdata.columns:
  column_test.append(col)
  null.append(testdata[col].isna().sum())
  pctgnull.append((testdata[col].isna().sum()/len(testdata))*100)
  tipe.append(getType(col))

NullTest = pd.DataFrame({'column':column_test, 'null':null, 'pctgnull':pctgnull, 'type':tipe})
NullTest[NullTest.null>0].sort_values(by='null', ascending=False).reset_index(drop = True)
# Out:
#           column  null   pctgnull          type
# 0         PoolQC  1456  99.794380       ordinal
# 1    MiscFeature  1408  96.504455       nominal
# 2          Alley  1352  92.666210       nominal
# 3          Fence  1169  80.123372       ordinal
# 4    FireplaceQu   730  50.034270       ordinal
# 5    LotFrontage   227  15.558602  quantitative
# 6     GarageCond    78   5.346127       ordinal
# 7    GarageYrBlt    78   5.346127  quantitative
# 8     GarageQual    78   5.346127       ordinal
# 9   GarageFinish    78   5.346127       ordinal
# 10    GarageType    76   5.209047       nominal
# 11      BsmtCond    45   3.084304       ordinal
# 12  BsmtExposure    44   3.015764       ordinal
# 13      BsmtQual    44   3.015764       ordinal
# 14  BsmtFinType1    42   2.878684       ordinal
# 15  BsmtFinType2    42   2.878684       ordinal
# 16    MasVnrType    16   1.096642       nominal
# 17    MasVnrArea    15   1.028101  quantitative
# 18      MSZoning     4   0.274160       nominal
# ...

# %%
df1 = NullTrain[NullTrain.null>0]
df2 = NullTest[NullTest.null>0]
pd.Series(list(set(df2["column"])-set(df1["column"]))).to_frame().T
# len(set(df2["column"]).intersection(set(df1["column"])))
# Out:
#            0           1          2         3           4           5   \
# 0  BsmtFinSF2  GarageArea  Utilities  MSZoning  GarageCars  BsmtFinSF1
#
#              6           7            8         9            10         11  \
# 0  BsmtHalfBath  Functional  KitchenQual  SaleType  Exterior2nd  BsmtUnfSF
#
#              12           13           14
# 0  BsmtFullBath  Exterior1st  TotalBsmtSF

# %% [markdown]
# Pada traindata terdapat 19 variabel memiliki data yang hilang. Untuk mengisi data yang hilang perlu dilihat tipe data dan value dari masing-masing variabel
#
# Pada testdata terdapat 33 variabel memiliki data yang hilang. 18 variabel diantaranya merupakan variabel yang sama dengan variabel pada traindata (Variabel Electrical pada traindata ada yang hilang  namun aman pada testdata)
#
# * Data yang hilang (MiscFeature, PoolQC) lebih hampir 100% saya memilih untuk membuang variabel tersebut. selain itu data-data tersebut telah diwakiliki oleh variabel lain yaitu $MiscVal dan PoolArea
# * Kasus data hilang pada variabel  Alley, Fence, dan FireplaceQu mengindikasikan rumah tersebut tidak memiliki variabel (fitur) yang dimaksud

# %%
for col in [ "Alley", "Fence", "FireplaceQu"]:
  traindata[col] = traindata[col].fillna("None")
traindata.drop(columns = ["MiscFeature", "PoolQC"], inplace = True)

for col in [ "Alley", "Fence", "FireplaceQu"]:
  testdata[col] = testdata[col].fillna("None")
testdata.drop(columns = ["MiscFeature", "PoolQC"], inplace = True)

# %% [markdown]
# **Garage**
#
# seluruh variabel yang berhubungan dengan Garage(GarageType, GarageYrBlt, GarageFinish, GarageCond, dan GarageQual) memiliki jumlah missing value yang sama yaitu 81. Asumsinya adalah missing value tersebut berada di row yang sama sehingga sebab hilangnya data adalah karena rumah tersebut tidak memiliki Garage. Untuk GarageYrBlt dapat diisi dengan 0

# %%
traindata.GarageYrBlt = traindata.GarageYrBlt.fillna(0)
for col in ["GarageType", "GarageFinish", "GarageCond", "GarageQual"]:
  traindata[col] = traindata[col].fillna("None")

testdata.GarageYrBlt = testdata.GarageYrBlt.fillna(0)
for col in ["GarageType", "GarageFinish", "GarageCond", "GarageQual"]:
  testdata[col] = testdata[col].fillna("None")

# %% [markdown]
# **Basement**
#
# BsmtFinType2, BsmtExposure, BsmtFinType1, BsmtQual, BsmtCond tidak memiliki jumlah missing value yang sama. Namun dari variabel data yang telah terdeskripsi dapat disimpulkan variabel-variabel tersebut memiliki missing value karena rumah terkait memang tidak memiliki basement

# %%
for col in ['BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtQual', 'BsmtCond']:
  traindata[col] = traindata[col].fillna("None")

for col in ['BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtQual', 'BsmtCond']:
  testdata[col] = testdata[col].fillna("None")

# %% [markdown]
# * Saya tidak memiliki informasi mengenai data electrical mengapa dia bisa hilang sehingga saya memutuskan untuk mengisinya sesuai dengan keinginan saya
# * Variabel MasVnrType dan MasVnrArea mungkin hilang karena memang tidak ada jadi bisa diisi dengan "None" dan 0

# %%
traindata["Electrical"] = traindata["Electrical"].fillna("SBrkr")
traindata["MasVnrType"] = traindata["MasVnrType"].fillna("None")
traindata["MasVnrArea"] = traindata["MasVnrArea"].fillna(0)

testdata["MasVnrType"] = testdata["MasVnrType"].fillna("None")
testdata["MasVnrArea"] = testdata["MasVnrArea"].fillna(0)

# %% [markdown]
# **Missing Value pada testdata**
# * data yang hilang merupakan data nominal sehingga pengisian datanya saya memilih menggunakan SimpleImputer dengan modusnya

# %%
miss_test = list(set(df2["column"])-set(df1["column"]))
tipe = []
for i in miss_test:
  tipe.append(getType(i))
pd.DataFrame({"TestCol" : miss_test, "Type" : tipe})
# Out:
#          TestCol          Type
# 0     BsmtFinSF2  quantitative
# 1     GarageArea  quantitative
# 2      Utilities       ordinal
# 3       MSZoning       nominal
# 4     GarageCars  quantitative
# 5     BsmtFinSF1  quantitative
# 6   BsmtHalfBath  quantitative
# 7     Functional       nominal
# 8    KitchenQual       ordinal
# 9       SaleType       nominal
# 10   Exterior2nd       nominal
# 11     BsmtUnfSF  quantitative
# 12  BsmtFullBath  quantitative
# 13   Exterior1st       nominal
# 14   TotalBsmtSF  quantitative

# %%
traindata["SaleType"].fillna("Oth")
testdata["SaleType"].fillna("Oth")
miss_test.remove("SaleType")
for col in miss_test:
  testdata[col].fillna(testdata[col].mode()[0], inplace=True)

# %% [markdown]
# **LotFrontage**
#
# terdapat hampir 20% data yang hilang, untuk mengisi 20% data yang hilang tersebut perlu dipahami bahwa LotFrontage merupakan data kontinu yang mungkin bisa diisi menggunakan 0, median, atau mean data tersebut. Namun, daripada menggunakan masukan yang sangat sederhana, saya dapat melatih model prediktif dari 80% data yang ada menggunakan variabel lain untuk memprediksi nilai yang hilang. Variabel yang mungkin mempengaruhi LotFrontage adalah ['LotFrontage', 'MSZoning', 'LotArea', 'LotShape', 'LotConfig', 'Condition1', 'BldgType', '1stFlrSF', 'GrLivArea', 'GarageArea']

# %%
COLS = ['LotFrontage', 'MSZoning', 'LotArea', 'LotShape', 'LotConfig', 'Condition1', 'BldgType', '1stFlrSF', 'GrLivArea', 'GarageArea']
for col in COLS:
  print(f"{col} => {getType(col)}")
# Out:
# LotFrontage => quantitative
# MSZoning => nominal
# LotArea => quantitative
# LotShape => nominal
# LotConfig => nominal
# Condition1 => ordinal
# BldgType => nominal
# 1stFlrSF => quantitative
# GrLivArea => quantitative
# GarageArea => quantitative

# %%
# Gabungkan Data yang ada pada testdata dan traindata agar mendapatkan data yang lebih banyak
LotDataPred = pd.concat([traindata[COLS], testdata[COLS]])
# Inisialisasi encoding pada data nominal dengan one-hot encoding
CAN_COLS = list(set(COLS) - set(QUANTITATIVE_COLS).intersection(set(COLS))) # ambil data nominal
oh_encoder = OneHotEncoder(handle_unknown = 'ignore', sparse_output=False)
oh_encoder.fit(LotDataPred[CAN_COLS])
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
# Pisahkan data dengan LotFrontage kosong dengan yang tidak
train_data = LotDataPred.loc[LotDataPred.LotFrontage.notna()]
test_data = LotDataPred.loc[LotDataPred.LotFrontage.isna()]

# one-hot encoding untuk data nominal
train_can = pd.DataFrame(oh_encoder.transform(train_data[CAN_COLS]))
test_can = pd.DataFrame(oh_encoder.transform(test_data[CAN_COLS]))

# %%
# One-hot encoding removed index; put it back
train_can.index = train_data.index
test_can.index = test_data.index

# Buang data nominal yang telah dilakukan one-hot encoding
train_num = train_data.drop(CAN_COLS, axis=1)
test_num = test_data.drop(CAN_COLS, axis=1)

# gabung hasil one-hot encoding dengan data sebelumnya
oh_train = pd.concat([train_num, train_can], axis=1)
oh_test = pd.concat([test_num, test_can], axis=1)

# Buat semua kolomnya jadi string
oh_train.columns = oh_train.columns.astype(str)
oh_test.columns = oh_test.columns.astype(str)

# %%
oh_train.dropna(inplace=True)

# %%
y = oh_train.LotFrontage
X = oh_train.drop('LotFrontage', axis=1)

LotFrontage_pipeline = Pipeline(steps=[('model', RandomForestRegressor(n_estimators=165, random_state=0)) # 165
                             ])
# Train the model on 5 folds
# Multiply by -1 since sklearn calculates *negative* MAE
scores = -1 * cross_val_score(LotFrontage_pipeline, X, y,
                              cv=5,
                              scoring='neg_mean_absolute_error')
# Create the target values using the mean method
mean_method_y = [y.mean() for i in y]
# Calculate the score for the mean method
mean_method_score = mean_absolute_error(y, mean_method_y)

print(f'MAE score for the trained model: {scores.mean()}\nMAE score for the dataset mean method: {mean_method_score}')
# Out:
# MAE score for the trained model: 8.537016131882615
# MAE score for the dataset mean method: 16.633666858744057

# %%
model = RandomForestRegressor(n_estimators=165, random_state=0)
model.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=165, random_state=0)

# %%
LotDataPred.loc[LotDataPred.LotFrontage.isnull(), 'LotFrontage'] = model.predict(oh_test.drop('LotFrontage', axis=1))

# %%
LotDataPredtrain = LotDataPred.groupby(LotDataPred.index).first()
print(len(LotDataPredtrain))
LotDataPredtest = LotDataPred.groupby(LotDataPred.index).nth(1)
print(len(LotDataPredtest))
# Out:
# 1460
# 1459

# %%
traindata.LotFrontage = LotDataPredtrain.loc[traindata.index].LotFrontage
testdata.LotFrontage = LotDataPredtest.loc[testdata.index].LotFrontage
traindata[QUANTITATIVE_COLS].isna().sum().to_frame().T
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0            0        0           0           0           0          0
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  GarageYrBlt  \
# 0            0         0         0             0          0            0
#
#    GarageArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0           0             0             0         0         0             0
#
#    KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  WoodDeckSF  \
# 0             0             0           0           0           0
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal
# 0            0              0          0            0         0        0

# %%
testdata.isna().sum().to_frame().T
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   0           0         0            0        0       0      0         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            0          0          0          0             0           0
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0           0         0           0            0            0          0
#
#    YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0             0          0         0            0            0           0
#
#    MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 0           0          0          0           0         0         0
#
#    BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# 0             0             0           0             0           0
#
#    BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# ...

# %% [markdown]
# ### Feature Enginering

# %% [markdown]
# #### Transformasi data quantitatif

# %%
plt.figure(figsize = (40,40))
sns.heatmap(traindata[QUANTITATIVE_COLS + ['SalePrice']].corr(), annot = True, cmap = plt.cm.Reds)
plt.show()

# %%
abs(traindata[QUANTITATIVE_COLS + ['SalePrice']].corr().SalePrice).sort_values()
# Out:
# BsmtFinSF2       0.004832
# BsmtHalfBath     0.005149
# MiscVal          0.020021
# LowQualFinSF     0.037963
# 3SsnPorch        0.054900
# PoolArea         0.069798
# ScreenPorch      0.121208
# KitchenAbvGr     0.147548
# EnclosedPorch    0.149050
# BedroomAbvGr     0.209044
# BsmtUnfSF        0.221985
# BsmtFullBath     0.236224
# LotArea          0.257320
# HalfBath         0.313982
# 2ndFlrSF         0.319300
# OpenPorchSF      0.321053
# WoodDeckSF       0.334135
# GarageYrBlt      0.349014
# LotFrontage      0.351584
# BsmtFinSF1       0.372023
# MasVnrArea       0.426775
# Fireplaces       0.489449
# TotRmsAbvGrd     0.534422
# FullBath         0.594771
# 1stFlrSF         0.596981
# TotalBsmtSF      0.612134
# GarageArea       0.650888
# GarageCars       0.680625
# GrLivArea        0.700927
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
# # # Lakukan transformasi pada variabel quantitatif agar setara dengan SalePrice
# for quan in QUANTITATIVE_COLS:
#   if np.abs(traindata[QUANTITATIVE_COLS + ['SalePrice']].corr().SalePrice[quan]) < np.abs(np.log(traindata[quan] +1).corr(traindata.SalePrice)):
#     traindata[quan] = np.log(traindata[quan]+1)
#     testdata[quan] = np.log(testdata[quan]+1)

# %% [markdown]
# #### Gabungkan Data

# %%
def calculate_VIF(df, cols):
    vif, tolerance = {}, {}
    for col in cols:
        # extract all the other cols you will regress against
        X = [f for f in cols if f != col]
        X, y = df[X], df[col]        # extract r-squared from the fit
        r2 = LinearRegression().fit(X, y).score(X, y)

        tolerance[col] = 1 - r2        # calculate tolerance
        vif[col] = 1/(tolerance[col])    # calculate VIF
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance}) # return VIF DataFrame

# %%
calculate_VIF(df = traindata, cols = QUANTITATIVE_COLS)
# Out:
#                     VIF  Tolerance
# LotFrontage    1.536481   0.650838
# LotArea        1.262898   0.791830
# MasVnrArea     1.359762   0.735423
# BsmtFinSF1          inf   0.000000
# BsmtFinSF2          inf   0.000000
# BsmtUnfSF           inf   0.000000
# TotalBsmtSF         inf   0.000000
# 1stFlrSF            inf   0.000000
# 2ndFlrSF            inf   0.000000
# LowQualFinSF        inf   0.000000
# GrLivArea           inf   0.000000
# GarageYrBlt    1.778494   0.562273
# GarageArea     5.336481   0.187389
# BsmtFullBath   2.141838   0.466889
# BsmtHalfBath   1.131727   0.883606
# FullBath       2.152706   0.464532
# HalfBath       1.889680   0.529190
# BedroomAbvGr   2.151778   0.464732
# KitchenAbvGr   1.276599   0.783331
# TotRmsAbvGrd   4.769979   0.209645
# Fireplaces     1.524568   0.655923
# GarageCars     5.767704   0.173379
# WoodDeckSF     1.194518   0.837157
# OpenPorchSF    1.208830   0.827246
# EnclosedPorch  1.131226   0.883997
# 3SsnPorch      1.019741   0.980641
# ...

# %% [markdown]
# Nilai tolerance = 0 terjadi karena terdapat hubungan yang sempurna antar variabel. kondisi tersebut menunjukkan adanya multikolinieritas
# * Pertama saya akan melakukan penanganan pada variabel yang memiliki multikolinieritas sempurna
# * saya akan membuat variabel baru yang masih saling berkaitan

# %%
col_inf = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea']
calculate_VIF(df=traindata, cols = col_inf)
# Out:
#               VIF  Tolerance
# BsmtFinSF1    inf        0.0
# BsmtFinSF2    inf        0.0
# BsmtUnfSF     inf        0.0
# TotalBsmtSF   inf        0.0
# 1stFlrSF      inf        0.0
# 2ndFlrSF      inf        0.0
# LowQualFinSF  inf        0.0
# GrLivArea     inf        0.0

# %% [markdown]
# **Variabel**
# * BsmtFinSF1 -> area basement tipe1 terselesaikan
# * BsmtFinSF2 -> area basement tipe2 terselesaikan
# * BsmtUnfSF -> area basement belum terselesaikan
# * TotalBsmtSF -> Total area basement
#
# BsmtFinSF1 + BsmtFinSF2 + BsmtUnfSf = TotalBsmtSF
#
# * 1stFlrSF -> area lantai pertama
# * 2ndFlrSF -> area lantai dua
# * LowQualFinSF ->
# * GrLivArea ->
#
# 1stFlrSF + 2ndFlrSF + LowQualFinSF = GrLivArea
#
# **Penanganan**
#
# * Buat Variabel baru bernama BsmtSF dengan menjumlahkan BsmtFinSF1 dan 2
# * Buat Variabel baru bernama FlrSF dengan menjumlahkan 1stFlrSF dan 2ndFlrSF
# * Buat Variabel baru dengan nama 2ndFlr yang menunjukkan rumah tersebut memiliki 2 lantai (1) atau tidak (0)
# * Variabel TotalBsmtSF dan GrLivArea dapat di drop
# * Drop variabel BsmtUnfSf dan LowQualFinSF

# %%
traindata["BsmtSF"] = traindata["BsmtFinSF1"] + traindata["BsmtFinSF2"]
traindata["FlrSF"] = traindata["1stFlrSF"] + traindata["2ndFlrSF"]
testdata["BsmtSF"] = testdata["BsmtFinSF1"] + testdata["BsmtFinSF2"]
testdata["FlrSF"] = testdata["1stFlrSF"] + testdata["2ndFlrSF"]
# Buat variabel yang menunjukkan rumah tersebut memiliki 2 lantai
traindata["2ndFlr"] = (traindata["2ndFlrSF"]!=0).astype(int)
testdata["2ndFlr"] = (testdata["2ndFlrSF"]!=0).astype(int)

# %%
traindata.drop(columns = ["TotalBsmtSF", "GrLivArea", "BsmtUnfSF", "LowQualFinSF", "BsmtFinSF1",
                          "BsmtFinSF2", "1stFlrSF", "2ndFlrSF"], axis = 1, inplace = True)
testdata.drop(columns = ["TotalBsmtSF", "GrLivArea", "BsmtUnfSF", "LowQualFinSF", "BsmtFinSF1",
                          "BsmtFinSF2", "1stFlrSF", "2ndFlrSF"], axis = 1, inplace = True)

# %% [markdown]
# **Membuat Variabel Baru dari Data Quantitatif**
# * Variabel RenovStat dari variabel YearBuilt dan YearRemodAdd
# * Variabel AgeHouse dari variabel YEarBuilt dan YrSold
# * Variabel TotalBath dari variabel BsmtFullBath, BsmtHalfBath, FullBath dan HalfBath (asumsikan Full atau Half ngga ada bedanya)
# * Variabel TotalPorch dari variabel OpenPorchSF, EnclosedPorch, 3SsnPorch, dan ScreenPorch
# * Variabel GarageCars dan GarageArea merepresentasikan luas Garage sehingga salah satu dari variabel tersebut harus didrop, saya memilih GarageCars untuk didrop karena tidak merepresentasikan luas secara spesifik

# %%
traindata["RenovStat"] = (traindata["YearBuilt"] != traindata["YearRemodAdd"]).astype(int)
traindata["AgeHouse"] = traindata["YrSold"] - traindata["YearBuilt"]
traindata["TotalBath"] = traindata["BsmtFullBath"] + traindata["BsmtHalfBath"] + traindata["FullBath"] + traindata["HalfBath"]
traindata["TotalPorch"] = traindata["OpenPorchSF"] + traindata["EnclosedPorch"] + traindata["3SsnPorch"] + traindata["ScreenPorch"]
traindata.drop(columns = ["GarageCars"], axis = 1, inplace = True)

testdata["RenovStat"] = (testdata["YearBuilt"] != testdata["YearRemodAdd"]).astype(int)
testdata["AgeHouse"] = testdata["YrSold"] - testdata["YearBuilt"]
testdata["TotalBath"] = testdata["BsmtFullBath"] + testdata["BsmtHalfBath"] + testdata["FullBath"] + testdata["HalfBath"]
testdata["TotalPorch"] = testdata["OpenPorchSF"] + testdata["EnclosedPorch"] + testdata["3SsnPorch"] + testdata["ScreenPorch"]
testdata.drop(columns = ["GarageCars"], axis = 1, inplace = True)

# %%
traindata.drop(columns = ["YearBuilt", "YearRemodAdd", "YrSold", "BsmtFullBath", "BsmtHalfBath", "FullBath",
                          "HalfBath", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch"], axis = 1, inplace = True)
testdata.drop(columns = ["YearBuilt", "YearRemodAdd", "YrSold", "BsmtFullBath", "BsmtHalfBath", "FullBath",
                          "HalfBath", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch"], axis = 1, inplace = True)

# %% [markdown]
# #### Label Encoding

# %% [markdown]
# **Data Ordinal**

# %%
def condition(df):
    df["Condition2"] = df["Condition2"].replace({"Norm":""}) # Norm berarti tidak ada kondisi kedua
    combined_condition = []
    for val1,val2 in zip(df["Condition1"],df["Condition2"]):
        if val2 == "":
            combined_condition.append(val1)
        elif val1==val2:
            combined_condition.append(val1)
        else:
            combined_condition.append(val1+val2)

    df["Combined_Condition"] = combined_condition
    df["ProximityStatus"] = (df["Combined_Condition"] == "Norm").astype(int)

condition(traindata)
condition(testdata)
traindata.drop(["Combined_Condition", "Condition1", "Condition2"], axis = 1, inplace=True)
testdata.drop(["Combined_Condition", "Condition1", "Condition2"], axis = 1, inplace=True)

# %%
ordinal_mappings = {
    'Utilities': {'ELO': 1, 'NoSeWa': 2, 'NoSewr': 3, 'AllPub': 4},
    'LandSlope': {'Gtl': 1, 'Mod': 2, 'Sev': 3},
    'ExterQual': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
    'ExterCond': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
    'BsmtQual': {'None':1, 'Po': 2, 'Fa': 3, 'TA': 4, 'Gd':5, 'Ex':6},
    'BsmtCond': {'None':1, 'Po': 2, 'Fa': 3, 'TA': 4, 'Gd':5, 'Ex':6},
    'BsmtExposure': {'None':1, 'No': 2, 'Mn': 3, 'Av': 4, 'Gd':5},
    'BsmtFinType1': {'None':1, 'Unf': 2, 'LwQ': 3, 'Rec': 4, 'BLQ':5, 'ALQ':6, 'GLQ':7},
    'BsmtFinType2': {'None':1, 'Unf': 2, 'LwQ': 3, 'Rec': 4, 'BLQ':5, 'ALQ':6, 'GLQ':7},
    'Heating' : {"Floor":1, "GasA":2, "GasW":3, "Grav":4, "OthW":5, "Wall":6},
    'HeatingQC': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
    'KitchenQual': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd':4, 'Ex':5},
    'FireplaceQu': {'None':1, 'Po': 2, 'Fa': 3, 'TA': 4, 'Gd':5, 'Ex':6},
    'GarageFinish': {'None':1, 'Unf': 2, 'RFn': 3, 'Fin': 4},
    'GarageQual': {'None':1, 'Po': 2, 'Fa': 3, 'TA': 4, 'Gd':5, 'Ex':6},
    'GarageCond': {'None':1, 'Po': 2, 'Fa': 3, 'TA': 4, 'Gd':5, 'Ex':6},
    'Fence': {'None':1, 'MnWw': 2, 'GdWo': 3, 'MnPrv':4, 'GdPrv':5}
}
for column, mapping in ordinal_mappings.items():
    traindata[column] = traindata[column].map(mapping)

for column, mapping in ordinal_mappings.items():
    testdata[column] = testdata[column].map(mapping)

# %%
traindata["ValHeating"] = traindata["Heating"] + traindata["HeatingQC"]
testdata["ValHeating"] = testdata["Heating"] + testdata["HeatingQC"]

traindata["GarageOvAll"] = traindata["GarageQual"] + traindata["GarageCond"]
testdata["GarageOvAll"] = testdata["GarageQual"] + testdata["GarageCond"]

traindata.drop(["GarageYrBlt", "MoSold"],axis = 1, inplace = True)
testdata.drop(["GarageYrBlt", "MoSold"],axis = 1, inplace = True)

# %%
df_test_id = testdata["Id"]
traindata.drop(["Id"], axis = 1, inplace = True)
testdata.drop(["Id"], axis = 1, inplace = True)

# %%
# Hapus variabel pada list
cols = ["TotalBsmtSF", "GrLivArea", "BsmtUnfSF", "LowQualFinSF", "BsmtFinSF1", "BsmtFinSF2", "1stFlrSF", "2ndFlrSF", "BsmtFullBath",
        "BsmtHalfBath", "FullBath", "HalfBath", "OpenPorchSF", "GarageYrBlt", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "GarageCars"]
for col in cols:
  QUANTITATIVE_COLS.remove(col)

for col in ["PoolQC", "YearBuilt", "YearRemodAdd", "YrSold", "Condition1", "Condition2", "Heating", "HeatingQC",
            "GarageYrBlt", "GarageQual", "GarageCond", "MoSold"]:
  ORDINAL_COLS.remove(col)

for col in ["MiscFeature", "Id"]:
  NOMINAL_COLS.remove(col)

# %%
add_quan = ["BsmtSF", "FlrSF", "AgeHouse", "TotalBath", "TotalPorch", "ProximityStatus"]
for i in add_quan:
  QUANTITATIVE_COLS.append(i)

add_ordi = ["2ndFlr", "RenovStat", "ValHeating", "GarageOvAll"]
for i in add_ordi:
  ORDINAL_COLS.append(i)

# %% [markdown]
# **Nominal Data**

# %%
unique_df = pd.Series({col: traindata[col].nunique() for col in NOMINAL_COLS})
unique_df.to_frame().T
# Out:
#    HouseStyle  CentralAir  Street  Functional  Exterior2nd  PavedDrive  \
# 0           8           2       2           7           16           3
#
#    LandContour  MasVnrType  Alley  RoofStyle  BldgType  LotConfig  Foundation  \
# 0            4           4      3          6         5          5           6
#
#    GarageType  Electrical  SaleCondition  Exterior1st  Neighborhood  SaleType  \
# 0           7           5              6           15            25         9
#
#    MSSubClass  MSZoning  LotShape  RoofMatl
# 0          15         5         4         8

# %%
unique_dfTest = pd.Series({col: testdata[col].nunique() for col in NOMINAL_COLS})
unique_dfTest.to_frame().T
# Out:
#    HouseStyle  CentralAir  Street  Functional  Exterior2nd  PavedDrive  \
# 0           7           2       2           7           15           3
#
#    LandContour  MasVnrType  Alley  RoofStyle  BldgType  LotConfig  Foundation  \
# 0            4           4      3          6         5          5           6
#
#    GarageType  Electrical  SaleCondition  Exterior1st  Neighborhood  SaleType  \
# 0           7           4              6           13            25         9
#
#    MSSubClass  MSZoning  LotShape  RoofMatl
# 0          16         5         4         4

# %% [markdown]
# **Kolom dengan jumlah unique dengan banyak yang sama**
#
# MasVnrType, SaleCondition, RoofStyle, Alley, GarageType, Street, Foundation, MSZoning, BldgType, LandContour, LotConfig, CentralAir, LotShape, Neighborhood, SaleType, PavedDrive, Functional. Kolom-kolom tersebut akan saya lakukan One-Hot Encoding
#
# **Kolom dengan jumlah banyak unique berbeda**
#
# Exterior2nd, RoofMatl, Exterior1st, HouseStyle, MSSubClass, Electrical. Kolom-kolom ini akan saya lakukan manual label encoding

# %%
othr = ["Exterior2nd", "RoofMatl", "Exterior1st", "HouseStyle", "MSSubClass", "Electrical"]
for i in othr:
  print(f"{i} => {traindata[i].unique()}\n")
print("+"*100)
print("+"*100,"\n")
for i in othr:
  print(f"{i} => {testdata[i].unique()}\n")
# Out:
# Exterior2nd => ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']
#
# RoofMatl => ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
#
# Exterior1st => ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
#
# HouseStyle => ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
#
# MSSubClass => [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
#
# Electrical => ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Exterior2nd => ['VinylSd' 'Wd Sdng' 'HdBoard' 'Plywood' 'MetalSd' 'Brk Cmn' 'CmentBd'
# ...

# %% [markdown]
# **RoofMatl, Exterior**
#
# Saya telah melakukan pencarian informasi mengenai value dari setiap material dan saya simpulkan nilai material paling rendah hingga paling tinggi berturut-turut adalah

# %%
other_train = {
    'RoofMatl' : {"Roll":1, "Membran":2, "Tar&Grv":3, "CompShg":4, "Metal":5, "ClyTile":6, "WdShake":7, "WdShngl":8},
    'Exterior1st': {"CBlock":1, "AsbShng":2, "AsphShn":3, "Plywood":4, "HdBoard":5, "BrkComm":6,
                    "CemntBd":8, "Stucco":9, "ImStucc":10, "MetalSd":11, "Stone":12,
                    "PreCast":13, "VinylSd":14, "Wd Sdng":15, "WdShing":16},
    'Exterior2nd' : {"CBlock":1, "AsbShng":2, "AsphShn":3, "Plywood":4, "HdBoard":5, "Brk Cmn":6,
                    "BrkFace":7, "CmentBd":8, "Stucco":9, "ImStucc":10, "MetalSd":11, "Stone":12,
                    "VinylSd":14, "Wd Sdng":15, "Wd Shng":16, "Other":17},
    'HouseStyle' : {'2Story':3, '1Story':6, '1.5Fin':4, '1.5Unf':5, 'SFoyer':7, 'SLvl':8, '2.5Unf':2, '2.5Fin':1}
}
other_test = {
    'RoofMatl' : {"Tar&Grv":3, "CompShg":4, "WdShake":7, "WdShngl":8},
    'Exterior1st': {"CBlock":1, "AsbShng":2, "AsphShn":3, "Plywood":4, "HdBoard":5, "BrkComm":6,
                    "BrkFace":7, "CemntBd":8, "Stucco":9, "MetalSd":11,
                    "VinylSd":14, "Wd Sdng":15, "WdShing":16},
    'Exterior2nd' : { "CBlock":1, "AsbShng":2, "AsphShn":3, "Plywood":4, "HdBoard":5, "Brk Cmn":6,
                    "BrkFace":7, "CmentBd":8, "Stucco":9, "ImStucc":10, "MetalSd":11, "Stone":12,
                    "VinylSd":14, "Wd Sdng":15, "Wd Shng":16},
    'HouseStyle' : {'1Story':6, '2Story':3, 'SLvl':8, '1.5Fin':4, 'SFoyer':7, '2.5Unf':2, '1.5Unf':5}
}

for column, mapping in other_train.items():
    traindata[column] = traindata[column].map(mapping)

for column, mapping in other_test.items():
    testdata[column] = testdata[column].map(mapping)

def exterior(df):
    extr = []
    for val1,val2 in zip(df["Exterior1st"],df["Exterior2nd"]):
        if val1 == val2:
            extr.append(val1)
        else:
            extr.append(val1+val2)
    df["Exterior"] = extr
    df.drop(["Exterior1st", "Exterior2nd"], axis = 1, inplace = True)

exterior(traindata)
exterior(testdata)

# %%
COLS = ["MasVnrType", "SaleCondition", "RoofStyle", "Alley", "GarageType", "Street", "Foundation", "MSZoning", "BldgType",
        "LandContour", "LotConfig", "CentralAir", "LotShape", "Neighborhood", "SaleType", "PavedDrive", "Functional"]
df_train =  pd.get_dummies(traindata[COLS])
df_test =  pd.get_dummies(testdata[COLS])

enc_traindata = pd.concat([df_train, traindata[ORDINAL_COLS], traindata[QUANTITATIVE_COLS+['SalePrice']]], axis=1)
enc_testdata = pd.concat([df_test, testdata[ORDINAL_COLS], testdata[QUANTITATIVE_COLS]], axis=1)
print(enc_traindata.shape)
print(enc_testdata.shape)
# Out:
# (1460, 140)
# (1459, 139)

# %% [markdown]
# # Evaluasi Model

# %%
x = enc_traindata.drop(columns = 'SalePrice')
y = enc_traindata['SalePrice']

# %%
x_train,x_test,y_train,y_test = train_test_split(x ,y, test_size=0.2, random_state=42)
print("Dimension of x_train:=>",x_train.shape)
print("Dimension of x_test:=>",x_test.shape)
print("Dimension of y_train:=>",y_train.shape)
print("Dimension of y_test:=>",y_test.shape)
# Out:
# Dimension of x_train:=> (1168, 139)
# Dimension of x_test:=> (292, 139)
# Dimension of y_train:=> (1168,)
# Dimension of y_test:=> (292,)

# %%
r2_value = []
adjusted_r2_value = []
mae_value = []
mse_value = []
rmse_value = []

def model_evaluation(algorithm):
    model = algorithm.fit(x_train, y_train)
    y_train_pred= model.predict(x_train)
    y_test_pred = model.predict(x_test)

    #Metrics Calculation.
    mae = mean_absolute_error(y_test,y_test_pred)
    mse = mean_squared_error(y_test,y_test_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test,y_test_pred)
    adjusted_r2 = 1 - ((1-r2)*(x_test.shape[0]-1)/(x_test.shape[0]-x_test.shape[1]-1))

    mae_value.append(mae)
    mse_value.append(mse)
    rmse_value.append(rmse)
    r2_value.append(r2)
    adjusted_r2_value.append(adjusted_r2)

    print(f"R2 Score of the {model} model is=>",r2)
    print(f"Adjusted R2 Score of the {model} model is=>",adjusted_r2)
    print()
    print(f"MAE of {model} model is=>",mae)
    print(f"MSE of {model} model is=>",mse)
    print(f"RMSE of {model} model is=>",rmse)

    # Scatter plot.
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.scatter(y_train, y_train_pred, color='blue', label='Train')
    plt.scatter(y_test, y_test_pred, color='red', label='Test')
    plt.xlabel('True values')
    plt.ylabel('Predicted values')
    plt.legend()
    plt.title('Scatter Plot',fontweight="black",size=20,pad=10)

    # Residual plot.
    plt.subplot(1,2,2)
    plt.scatter(y_train_pred, y_train_pred - y_train, color='blue', label='Train')
    plt.scatter(y_test_pred, y_test_pred - y_test, color='red', label='Test')
    plt.axhline(y=0, color='black', linestyle='--')
    plt.xlabel('Predicted values')
    plt.ylabel('Residuals')
    plt.legend()
    plt.title('Residual Plot',fontweight="black",size=20,pad=10)
    plt.show()

# %%
model_evaluation(RandomForestRegressor())
# Out:
# R2 Score of the RandomForestRegressor() model is=> 0.8822263576488862
# Adjusted R2 Score of the RandomForestRegressor() model is=> 0.7745254610251704
#
# MAE of RandomForestRegressor() model is=> 0.09885853316577711
# MSE of RandomForestRegressor() model is=> 0.021978153756010605
# RMSE of RandomForestRegressor() model is=> 0.1482503077771193

# %%
model_evaluation(CatBoostRegressor())
# Out:
# Learning rate set to 0.04196
# 0:	learn: 0.3800019	total: 53.3ms	remaining: 53.3s
# 1:	learn: 0.3704493	total: 57.5ms	remaining: 28.7s
# 2:	learn: 0.3606427	total: 61.7ms	remaining: 20.5s
# 3:	learn: 0.3516868	total: 65.7ms	remaining: 16.4s
# 4:	learn: 0.3431504	total: 69.7ms	remaining: 13.9s
# 5:	learn: 0.3340802	total: 73.8ms	remaining: 12.2s
# 6:	learn: 0.3260127	total: 77.8ms	remaining: 11s
# 7:	learn: 0.3184265	total: 81.9ms	remaining: 10.2s
# 8:	learn: 0.3110629	total: 85.9ms	remaining: 9.46s
# 9:	learn: 0.3041284	total: 89.8ms	remaining: 8.89s
# 10:	learn: 0.2970619	total: 93.7ms	remaining: 8.43s
# 11:	learn: 0.2904287	total: 97.6ms	remaining: 8.03s
# 12:	learn: 0.2842980	total: 102ms	remaining: 7.71s
# 13:	learn: 0.2777113	total: 106ms	remaining: 7.44s
# 14:	learn: 0.2717662	total: 110ms	remaining: 7.21s
# 15:	learn: 0.2657659	total: 114ms	remaining: 6.99s
# 16:	learn: 0.2597559	total: 118ms	remaining: 6.82s
# 17:	learn: 0.2545361	total: 123ms	remaining: 6.71s
# ...

# %%
model_evaluation(LGBMRegressor())
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000920 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2159
# [LightGBM] [Info] Number of data points in the train set: 1168, number of used features: 101
# [LightGBM] [Info] Start training from score 12.030652
# R2 Score of the LGBMRegressor() model is=> 0.8924235889497527
# Adjusted R2 Score of the LGBMRegressor() model is=> 0.7940477920024871
#
# MAE of LGBMRegressor() model is=> 0.09339665293027351
# MSE of LGBMRegressor() model is=> 0.020075212546568365
# RMSE of LGBMRegressor() model is=> 0.14168702321161372

# %%
model_evaluation(LinearRegression())
# Out:
# R2 Score of the LinearRegression() model is=> 0.9075710687899057
# Adjusted R2 Score of the LinearRegression() model is=> 0.8230472435385694
#
# MAE of LinearRegression() model is=> 0.09553059759719432
# MSE of LinearRegression() model is=> 0.01724848804100837
# RMSE of LinearRegression() model is=> 0.13133349930999466

# %%
model_evaluation(GradientBoostingRegressor())
# Out:
# R2 Score of the GradientBoostingRegressor() model is=> 0.9028841357294257
# Adjusted R2 Score of the GradientBoostingRegressor() model is=> 0.8140742335346243
#
# MAE of GradientBoostingRegressor() model is=> 0.09055958387284
# MSE of GradientBoostingRegressor() model is=> 0.018123133109216892
# RMSE of GradientBoostingRegressor() model is=> 0.13462218654150918

# %%
model_evaluation(XGBRegressor())
# Out:
# R2 Score of the XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) model is=> 0.8696778599564587
# Adjusted R2 Score of the XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
# ...

# %%
model_evaluation(AdaBoostRegressor())
# Out:
# R2 Score of the AdaBoostRegressor() model is=> 0.8259880789655801
# Adjusted R2 Score of the AdaBoostRegressor() model is=> 0.666858756440683
#
# MAE of AdaBoostRegressor() model is=> 0.13930285958699234
# MSE of AdaBoostRegressor() model is=> 0.032472976801307965
# RMSE of AdaBoostRegressor() model is=> 0.18020259931895535

# %%
model_evaluation(SVR())
# Out:
# R2 Score of the SVR() model is=> 0.7103082159555874
# Adjusted R2 Score of the SVR() model is=> 0.4453927029149731
#
# MAE of SVR() model is=> 0.16419046864408687
# MSE of SVR() model is=> 0.05406040302803722
# RMSE of SVR() model is=> 0.23250893107155524

# %%
from sklearn.tree import DecisionTreeRegressor
model_evaluation(DecisionTreeRegressor())
# Out:
# R2 Score of the DecisionTreeRegressor() model is=> 0.7813275045053555
# Adjusted R2 Score of the DecisionTreeRegressor() model is=> 0.5813572619148581
#
# MAE of DecisionTreeRegressor() model is=> 0.14004492547680844
# MSE of DecisionTreeRegressor() model is=> 0.040807243728302564
# RMSE of DecisionTreeRegressor() model is=> 0.2020080288708906

# %%
algorithms = ["RandomForest", "CatBoost", "LGBM", "Linear", "GradientBoosting",
              "XGB", "AdaBoost", "SVR", "DecisionTree"]

model_comparison = pd.DataFrame({"Model":algorithms,"R2_Score":r2_value,"Adjusted_R2_Score":adjusted_r2_value,
                       "MAE":mae_value,"MSE":mse_value,"RMSE":rmse_value})

model_comparison.sort_values(by='RMSE').reset_index().drop("index", axis = 1)
# Out:
#               Model  R2_Score  Adjusted_R2_Score       MAE       MSE      RMSE
# 0          CatBoost  0.911790           0.831124  0.084314  0.016461  0.128301
# 1            Linear  0.907571           0.823047  0.095531  0.017248  0.131333
# 2  GradientBoosting  0.902884           0.814074  0.090560  0.018123  0.134622
# 3              LGBM  0.892424           0.794048  0.093397  0.020075  0.141687
# 4      RandomForest  0.882226           0.774525  0.098859  0.021978  0.148250
# 5               XGB  0.869678           0.750502  0.103526  0.024320  0.155948
# 6          AdaBoost  0.825988           0.666859  0.139303  0.032473  0.180203
# 7      DecisionTree  0.781328           0.581357  0.140045  0.040807  0.202008
# 8               SVR  0.710308           0.445393  0.164190  0.054060  0.232509

# %% [markdown]
# # HyperParameter Tuning

# %% [markdown]
# #### CatBoost

# %%
param_grid1 = {
          'depth': [None, 6, 8, 10],
          'learning_rate' : [None, 0.01, 0.05] #,'l2_leaf_reg': [None, 1, 3]
}
CV_cb = GridSearchCV(estimator = CatBoostRegressor(), param_grid = param_grid1, cv = 5, n_jobs = -1)
CV_cb.fit(x_train, y_train)

# %%
best_parameters1 = CV_cb.best_params_
best_parameters1

# %% [markdown]
# #### GradientBoosting

# %%
param_grid2 = {
    'n_estimators': [100,120,140],
    'learning_rate': [0.13, 0.14, 0.15],
    'max_depth': [None, 4, 8]
}
CV_gb = GridSearchCV(estimator = GradientBoostingRegressor(), param_grid = param_grid2, cv = 5, n_jobs=-1)
CV_gb.fit(x_train, y_train)

# %%
best_parameters2 = CV_gb.best_params_
best_parameters2

# %% [markdown]
# #### LGBM

# %%
param_grid3 = {
    'learning_rate' : [0.12, 0.13, 0.15],
    'n_estimators': [100, 120, 140],
    'max_depth': [None, 6, 10],
    'num_leaves': [31, 62]
}
CV_lgbm = GridSearchCV(estimator = LGBMRegressor(), param_grid = param_grid3, cv = 5, n_jobs=-1)
CV_lgbm.fit(x_train, y_train)

# %%
best_parameters3 = CV_lgbm.best_params_
best_parameters3

# %% [markdown]
# **Note** : Gunakan lebih banyak parameter untuk mendapatkan hasil yang terbaik

# %% [markdown]
# ### Stacking Model

# %%
CatBoost_model = CatBoostRegressor()
GradBoost_model = GradientBoostingRegressor()
LGBM_model = LGBMRegressor()
LM_model = LinearRegression()

# %%
stack_model = StackingCVRegressor(regressors=(CatBoost_model, GradBoost_model, LGBM_model, LM_model),
                                  meta_regressor = CatBoost_model,
                                  use_features_in_secondary=True)
stack_model.fit(x_train, y_train)
# model_evaluation(stack_model)

# %%
import joblib
joblib.dump(stack_model, 'AdvanceHousePrice.pkl')
# Out:
# ['AdvanceHousePrice.pkl']

# %% [markdown]
# # Submission

# %%
prediction = stack_model.predict(enc_testdata)
output_df = df_test_id.to_frame()
output_df["SalePrice"] = prediction
output_df["SalePrice"] = np.exp(output_df["SalePrice"])
output_df.to_csv('submission.csv',index=False, quoting=2)
